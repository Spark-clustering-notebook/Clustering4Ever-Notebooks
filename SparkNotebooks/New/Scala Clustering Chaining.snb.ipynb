// %%
import smile.plot._
import scala.io.Source
import scala.collection.{immutable, mutable, parallel, GenSeq}
import org.clustering4ever.scala.clustering.kcenters.{KCentersModel, KCentersArgs, KCenters, KMeans, KMeansArgs}
import org.clustering4ever.math.distances.scalar.{Euclidean, Cosine, Minkowski}
import org.clustering4ever.indices.{ExternalIndicesLocal, InternalIndicesLocal}
import org.clustering4ever.enums.NmiNormalizationNature._
import org.clustering4ever.enums.ExternalsIndices
import org.clustering4ever.enums.InternalsIndices
import org.clustering4ever.util.ScalaImplicits._
import org.clustering4ever.clusterizables.EasyClusterizable
import org.clustering4ever.vectorizables.Vectorizable
import org.clustering4ever.vectors.ScalarVector
import org.clustering4ever.vectorizations.{VectorizationNature, Scalar, Default}
import org.clustering4ever.scala.clustering.rla.{RLAArgs, RLAArgsScalar, RLA, RLAScalar}
import org.clustering4ever.shapeless.{VMapping, VectorizationMapping}
import org.clustering4ever.clustering.chaining.ClusteringChainingLocal
import scala.collection.parallel
import scala.collection.parallel.mutable.ParArray
import org.clustering4ever.clustering.indices.ClustersIndicesAnalysisLocal
// Out:
// import smile.plot._
// import scala.io.Source
// import scala.collection.{immutable, mutable, parallel, GenSeq}
// import org.clustering4ever.scala.clustering.kcenters.{KCentersModel, KCentersArgs, KCenters, KMeans, KMeansArgs}
// import org.clustering4ever.math.distances.scalar.{Euclidean, Cosine, Minkowski}
// import org.clustering4ever.indices.{ExternalIndicesLocal, InternalIndicesLocal}
// import org.clustering4ever.enums.NmiNormalizationNature._
// import org.clustering4ever.enums.ExternalsIndices
// import org.clustering4ever.enums.InternalsIndices
// import org.clustering4ever.util.ScalaImplicits._
// import org.clustering4ever.clusterizables.EasyClusterizable
// import org.clustering4ever.vectorizables.Vectorizable
// import org.clustering4ever.vectors.ScalarVector
// import org.clustering4ever.vectorizations.{Vector...

// %%
:sh wget -P /tmp/ http://www.clustering4ever.org/Datasets/Aggregation/aggregation.csv
:sh wget -P /tmp/ http://www.clustering4ever.org/Datasets/Aggregation/labels
// Out:
// java.lang.RuntimeException: Nonzero exit value: 4
//   at scala.sys.package$.error(package.scala:27)
//   at scala.sys.process.ProcessBuilderImpl$AbstractBuilder.slurp(ProcessBuilderImpl.scala:132)
//   at scala.sys.process.ProcessBuilderImpl$AbstractBuilder.$bang$bang(ProcessBuilderImpl.scala:103)
//   ... 75 elided

// %%
val datasetSize = 100000
val dim = 10
val path = "/tmp/aggregation.csv"
val useAggregationDS = true

val rawData = if(useAggregationDS) Source.fromFile(path).getLines.map( x => mutable.ArrayBuffer(x.split(",").map(_.toDouble):_*) ).toBuffer
  else mutable.ArrayBuffer.fill(datasetSize)(mutable.ArrayBuffer.fill(dim)(scala.util.Random.nextDouble))
val groundTruePath = "/tmp/labels"
// Out:
// datasetSize: Int = 100000
// dim: Int = 10
// path: String = /tmp/aggregation.csv
// useAggregationDS: Boolean = true
// rawData: scala.collection.mutable.Buffer[scala.collection.mutable.ArrayBuffer[Double]] = ArrayBuffer(ArrayBuffer(15.55, 28.65), ArrayBuffer(14.9, 27.55), ArrayBuffer(14.45, 28.35), ArrayBuffer(14.15, 28.8), ArrayBuffer(13.75, 28.05), ArrayBuffer(13.35, 28.45), ArrayBuffer(13.0, 29.15), ArrayBuffer(13.45, 27.5), ArrayBuffer(13.6, 26.5), ArrayBuffer(12.8, 27.35), ArrayBuffer(12.4, 27.85), ArrayBuffer(12.3, 28.4), ArrayBuffer(12.2, 28.65), ArrayBuffer(13.4, 25.1), ArrayBuffer(12.95, 25.95), ArrayBuffer(12.9, 26.5), ArrayBuffer(11.85, 27.0), ArrayBuffer(11.35, 28.0), ArrayBuffer(11.15, 28.7), ArrayBuffer(11.25, 27.4), ArrayBuffer(10.75, 27.7), ArrayBuffer(10.5, 28.35), ArrayBuffer(9....

// %% [markdown]
// ## Transform your dataset adequately

// %%
val parData = rawData.zipWithIndex.toParArray.map{ case (v, id) => EasyClusterizable(id.toLong, ScalarVector(v)) }
// Out:
// parData: scala.collection.parallel.mutable.ParArray[org.clustering4ever.clusterizables.EasyClusterizable[Long,org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]]]] = ParArray(EasyClusterizable(0,Vectorizable(ScalarVector(ArrayBuffer(15.55, 28.65))),ScalarVector(ArrayBuffer(15.55, 28.65)),shapeless.HMap@4b1ab51d,Vector()), EasyClusterizable(1,Vectorizable(ScalarVector(ArrayBuffer(14.9, 27.55))),ScalarVector(ArrayBuffer(14.9, 27.55)),shapeless.HMap@51e1d76f,Vector()), EasyClusterizable(2,Vectorizable(ScalarVector(ArrayBuffer(14.45, 28.35))),ScalarVector(ArrayBuffer(14.45, 28.35)),shapeless.HMap@6202b7f8,Vector()), EasyClusterizable(3,Vectorizable(ScalarVector(ArrayBuff...

// %% [markdown]
// ## Let's try two metrics
//
// ### For every metrics you have to precise the nature of your vector (List[Int], Vector[Double], mutable.ArrayBuffer[Int],...)

// %%
val metric = new Euclidean[mutable.ArrayBuffer[Double]](false)
val metric2 = new Minkowski[mutable.ArrayBuffer[Double]](4)
// Out:
// metric: org.clustering4ever.math.distances.scalar.Euclidean[scala.collection.mutable.ArrayBuffer[Double]] = Euclidean distance without squared root applied
// metric2: org.clustering4ever.math.distances.scalar.Minkowski[scala.collection.mutable.ArrayBuffer[Double]] = Minkowski(4,3)

// %% [markdown]
// ## Instantiae the clustering chaining tool

// %%
val cc = new ClusteringChainingLocal(parData)
// Out:
// cc: org.clustering4ever.clustering.chaining.ClusteringChainingLocal[Long,org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],org.clustering4ever.clusterizables.EasyClusterizable,scala.collection.parallel.mutable.ParArray] = ClusteringChainingLocal(ParArray(EasyClusterizable(0,Vectorizable(ScalarVector(ArrayBuffer(15.55, 28.65))),ScalarVector(ArrayBuffer(15.55, 28.65)),shapeless.HMap@4b1ab51d,Vector()), EasyClusterizable(1,Vectorizable(ScalarVector(ArrayBuffer(14.9, 27.55))),ScalarVector(ArrayBuffer(14.9, 27.55)),shapeless.HMap@51e1d76f,Vector()), EasyClusterizable(2,Vectorizable(ScalarVector(ArrayBuffer(14.45, 28.35))),ScalarVector(ArrayBuffer(14.45, 28.35)),shapeles...

// %% [markdown]
// ## Two ways to prepare algorithm to test
// ### The painfull one

// %%
val rlaArgs = RLAArgsScalar(metric, 2D)
val kMeansArgs = KMeansArgs(2, metric, 0.0001, 50)
val kMeans = KMeans[
    Long,
    ScalarVector[mutable.ArrayBuffer[Double]],
    mutable.ArrayBuffer[Double],
    EasyClusterizable,
    Euclidean,
    ParArray
](kMeansArgs)
val rla = RLAScalar[
    Long,
    ScalarVector[mutable.ArrayBuffer[Double]],
    mutable.ArrayBuffer[Double],
    EasyClusterizable,
    Euclidean,
    ParArray
](rlaArgs)

val kMeansVariousK = (3 to 9).map{ i =>
  KMeans[
    Long,
    ScalarVector[mutable.ArrayBuffer[Double]],
    mutable.ArrayBuffer[Double],
    EasyClusterizable,
    Euclidean,
    ParArray
  ](
    KMeansArgs(i, metric, 0.0001, 50)
  )
}

val algosObtainedPainfully = Seq(kMeans, rla) ++ kMeansVariousK
// Out:
// rlaArgs: org.clustering4ever.scala.clustering.rla.RLAArgsScalar[scala.collection.mutable.ArrayBuffer[Double],org.clustering4ever.math.distances.scalar.Euclidean] = RLAArgsScalar(Euclidean distance without squared root applied,2.0)
// kMeansArgs: org.clustering4ever.scala.clustering.kcenters.KMeansArgs[scala.collection.mutable.ArrayBuffer[Double],org.clustering4ever.math.distances.scalar.Euclidean] = KMeansArgs(2,Euclidean distance without squared root applied,1.0E-4,50,Map())
// kMeans: org.clustering4ever.scala.clustering.kcenters.KMeans[Long,org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],scala.collection.mutable.ArrayBuffer[Double],org.clustering4ever.clusterizables.EasyClusterizable,org.clustering4ever.math.distances.scalar.Euclidean,scala.collection...

// %% [markdown]
// ## Easily using right methods

// %%
val kmeansArgsCombinations = KMeans.generateAnyArgumentsCombination((4 until 100), Seq(metric, metric2), Seq(5D), Seq(50, 100, 200))

val othersKmeansArgsCombinations = (23 to 30).map( i => KMeansArgs(i, metric, 0.0001, 50) )

val kmeansAlgos = kmeansArgsCombinations.map(_.obtainAlgorithm(parData)).toBuffer
val others = othersKmeansArgsCombinations.map(_.obtainAlgorithm(parData)).toSeq
// Out:
// kmeansArgsCombinations: Seq[org.clustering4ever.scala.clustering.kcenters.KMeansArgs[scala.collection.mutable.ArrayBuffer[Double],org.clustering4ever.math.distances.ContinuousDistance]] = Vector(KMeansArgs(4,Euclidean distance without squared root applied,5.0,50,Map()), KMeansArgs(4,Euclidean distance without squared root applied,5.0,100,Map()), KMeansArgs(4,Euclidean distance without squared root applied,5.0,200,Map()), KMeansArgs(4,Minkowski(4,3),5.0,50,Map()), KMeansArgs(4,Minkowski(4,3),5.0,100,Map()), KMeansArgs(4,Minkowski(4,3),5.0,200,Map()), KMeansArgs(5,Euclidean distance without squared root applied,5.0,50,Map()), KMeansArgs(5,Euclidean distance without squared root applied,5.0,100,Map()), KMeansArgs(5,Euclidean distance without squared root applied,5.0,200,Map()), KMeansArgs(...

// %% [markdown]
// ## Two methods to launch multiple algorithms PARALLELY
//
// Deeper test are necessary to choose the right one

// %%
val t0 = System.currentTimeMillis
val cc2 = cc.runAlgorithms(kmeansAlgos:_*)
val t1 = System.currentTimeMillis
val cc3 = cc2.runAlgorithms2(others:_*)
val t2 = System.currentTimeMillis

(t2 - t1).toDouble / (t1 - t0)
// Out:
// t0: Long = 1547417522091
// cc2: org.clustering4ever.clustering.chaining.ClusteringChainingLocal[Long,org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],org.clustering4ever.clusterizables.EasyClusterizable,scala.collection.parallel.mutable.ParArray] = ClusteringChainingLocal(ParArray(EasyClusterizable(0,Vectorizable(ScalarVector(ArrayBuffer(15.55, 28.65))),ScalarVector(ArrayBuffer(15.55, 28.65)),shapeless.HMap@4b1ab51d,Vector(0, 3, 1, 0, 2, 2, 4, 2, 1, 2, 1, 3, 5, 2, 3, 2, 5, 1, 1, 6, 0, 2, 0, 3, 0, 4, 3, 7, 1, 1, 4, 4, 3, 6, 7, 7, 5, 8, 2, 0, 3, 2, 4, 9, 6, 5, 0, 4, 0, 9, 6, 4, 8, 11, 7, 3, 10, 12, 0, 12, 9, 0, 7, 2, 10, 12, 0, 5, 7, 0, 4, 3, 4, 9, 0, 11, 7, 7, 14, 0,...
// 0.006788138620936048

// %% [markdown]
// ## Each run release a new clustering chaining object, with updated values

// %%
val t0 = System.currentTimeMillis
val newCC = cc3.runAlgorithms(algosObtainedPainfully:_*)
val t1 = System.currentTimeMillis

(t1 - t0) / 10000000D
// Out:
// t0: Long = 1547417540353
// newCC: org.clustering4ever.clustering.chaining.ClusteringChainingLocal[Long,org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],org.clustering4ever.clusterizables.EasyClusterizable,scala.collection.parallel.mutable.ParArray] = ClusteringChainingLocal(ParArray(EasyClusterizable(0,Vectorizable(ScalarVector(ArrayBuffer(15.55, 28.65))),ScalarVector(ArrayBuffer(15.55, 28.65)),shapeless.HMap@4b1ab51d,Vector(0, 3, 1, 0, 2, 2, 4, 2, 1, 2, 1, 3, 5, 2, 3, 2, 5, 1, 1, 6, 0, 2, 0, 3, 0, 4, 3, 7, 1, 1, 4, 4, 3, 6, 7, 7, 5, 8, 2, 0, 3, 2, 4, 9, 6, 5, 0, 4, 0, 9, 6, 4, 8, 11, 7, 3, 10, 12, 0, 12, 9, 0, 7, 2, 10, 12, 0, 5, 7, 0, 4, 3, 4, 9, 0, 11, 7, 7, 14, ...
// 1.38E-5

// %% [markdown]
// ## Get some informations about your process

// %%
newCC.data.last.clusterIDs
newCC.globalClusteringRunNumber
newCC.clusteringInfo.clusteringInformations.take(2)
// Out:
// <console>:124: warning: a pure expression does nothing in statement position; you may be omitting necessary parentheses
//        newCC.globalClusteringRunNumber
//              ^
// res12: scala.collection.immutable.Vector[(org.clustering4ever.types.ClusteringInformationTypes.GlobalClusteringRunNumber, org.clustering4ever.vectorizations.EmployedVectorization, org.clustering4ever.clustering.ClusteringArgs[_], org.clustering4ever.clustering.ClusteringModelCz[Long, org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]], _, org.clustering4ever.clusterizables.EasyClusterizable, scala.collection.parallel.mutable.ParArray])] = Vector((577,IthVectorization(0,None,org.clustering4ever.vectorizations.Default$@552b355f),KMeansArgs(23,Euclidean distance without squared root applied,1.0E-4,50,Map()),KMeansModel(Map(17 -> ScalarVector(ArrayBuffer(30.785416666666666, 23.125)), 8 -> ScalarVector(ArrayBuffer(21.253623188405797, 5.145652173913043)), 11...
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon485942c2dc879f3fd6d16802cd7091c7&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;589049658&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul589049658"><li>
//               <a href="#tab589049658-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab589049658-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab589049658"><div class="tab-pane" id="tab589049658-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anone5f7d661506cade40a8daee9b6eb8f7e&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:577,&quot;_2&quot;:&quot;IthVectorization(0,None,org.clustering4ever.vectorizations.Default$@552b355f)&quot;,&quot;_3&quot;:&quot;KMeansArgs(23,Euclidean distance without squared root applied,1.0E-4,50,Map())&quot;,&quot;_4&quot;:&quot;KMeansModel(Map(17 -&gt; ScalarVector(ArrayBuffer(30.785416666666666, 23.125)), 8 -&gt; ScalarVector(ArrayBuffer(21.253623188405797, 5.145652173913043)), 11 -&gt; ScalarVector(ArrayBuffer(12.720833333333331, 27.59166666666667)), 20 -&gt; ScalarVector(ArrayBuffer(5.679999999999999, 24.163333333333338)), 2 -&gt; ScalarVector(ArrayBuffer(32.74166666666667, 26.333333333333332)), 5 -&gt; ScalarVector(ArrayBuffer(20.011363636363637, 22.78409090909091)), 14 -&gt; ScalarVector(ArrayBuffer(33.268181818181816, 17.30909090909091)), 13 -&gt; ScalarVector(ArrayBuffer(9.893181818181818, 18.81590909090909)), 4 -&gt; ScalarVector(ArrayBuffer(6.634285714285714, 3.584285714285714)), 22 -&gt; ScalarVector(ArrayBuffer(10.527586206896551, 23.101724137931036)), 16 -&gt; ScalarVector(ArrayBuffer(13.713076923076924, 9.257692307692308)), 7 -&gt; ScalarVector(ArrayBuffer(15.043382352941178, 4.597794117647059)), 1 -&gt; ScalarVector(ArrayBuffer(8.604347826086956, 26.613043478260874)), 10 -&gt; ScalarVector(ArrayBuffer(13.216666666666667, 18.458333333333332)), 19 -&gt; ScalarVector(ArrayBuffer(34.731818181818184, 21.946969696969695)), 18 -&gt; ScalarVector(ArrayBuffer(23.00869565217391, 23.213043478260868)), 9 -&gt; ScalarVector(ArrayBuffer(6.587500000000001, 20.270833333333332)), 21 -&gt; ScalarVector(ArrayBuffer(31.145454545454548, 19.436363636363637)), 3 -&gt; ScalarVector(ArrayBuffer(7.44861111111111, 11.752777777777778)), 12 -&gt; ScalarVector(ArrayBuffer(33.029411764705884, 5.5058823529411764)), 15 -&gt; ScalarVector(ArrayBuffer(31.871794871794872, 10.966666666666667)), 6 -&gt; ScalarVector(ArrayBuffer(35.050000000000004, 9.130357142857141)), 0 -&gt; ScalarVector(ArrayBuffer(19.761029411764707, 9.766911764705881))),Euclidean distance without squared root applied,KMeansArgs(23,Euclidean distance without squared root applied,1.0E-4,50,Map()))&quot;},{&quot;_1&quot;:578,&quot;_2&quot;:&quot;IthVectorization(0,None,org.clustering4ever.vectorizations.Default$@552b355f)&quot;,&quot;_3&quot;:&quot;KMeansArgs(24,Euclidean distance without squared root applied,1.0E-4,50,Map())&quot;,&quot;_4&quot;:&quot;KMeansModel(Map(23 -&gt; ScalarVector(ArrayBuffer(33.35166666666667, 26.118333333333332)), 17 -&gt; ScalarVector(ArrayBuffer(7.4391891891891895, 25.804054054054053)), 8 -&gt; ScalarVector(ArrayBuffer(31.930263157894736, 18.623684210526317)), 11 -&gt; ScalarVector(ArrayBuffer(20.08478260869565, 22.745652173913047)), 20 -&gt; ScalarVector(ArrayBuffer(9.515853658536585, 20.592682926829273)), 2 -&gt; ScalarVector(ArrayBuffer(12.136486486486486, 26.741891891891886)), 5 -&gt; ScalarVector(ArrayBuffer(20.845555555555556, 9.637777777777778)), 14 -&gt; ScalarVector(ArrayBuffer(22.387500000000003, 5.6715909090909085)), 13 -&gt; ScalarVector(ArrayBuffer(31.07608695652174, 8.854347826086956)), 4 -&gt; ScalarVector(ArrayBuffer(33.29642857142857, 5.189285714285715)), 22 -&gt; ScalarVector(ArrayBuffer(34.80833333333333, 21.22833333333333)), 16 -&gt; ScalarVector(ArrayBuffer(16.197115384615387, 10.146153846153847)), 7 -&gt; ScalarVector(ArrayBuffer(18.17307692307692, 4.391346153846153)), 1 -&gt; ScalarVector(ArrayBuffer(12.392187500000002, 8.1421875)), 10 -&gt; ScalarVector(ArrayBuffer(5.65483870967742, 21.740322580645163)), 19 -&gt; ScalarVector(ArrayBuffer(35.21739130434783, 8.56086956521739)), 18 -&gt; ScalarVector(ArrayBuffer(13.836904761904758, 4.670238095238095)), 9 -&gt; ScalarVector(ArrayBuffer(6.517647058823529, 3.541176470588235)), 21 -&gt; ScalarVector(ArrayBuffer(9.942857142857141, 11.278571428571427)), 3 -&gt; ScalarVector(ArrayBuffer(23.068181818181817, 23.272727272727273)), 12 -&gt; ScalarVector(Ar ...
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["_1","_2","_3","_4"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anone55703a28b7364362dcb354ce5721276&quot;,&quot;initialValue&quot;:&quot;2&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon371ec4575645a526f7e543f510cfac06&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab589049658-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon4c66e0f2aa6f75aacedce768cd3f189f&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:577,&quot;_2&quot;:&quot;IthVectorization(0,None,org.clustering4ever.vectorizations.Default$@552b355f)&quot;,&quot;_3&quot;:&quot;KMeansArgs(23,Euclidean distance without squared root applied,1.0E-4,50,Map())&quot;,&quot;_4&quot;:&quot;KMeansModel(Map(17 -&gt; ScalarVector(ArrayBuffer(30.785416666666666, 23.125)), 8 -&gt; ScalarVector(ArrayBuffer(21.253623188405797, 5.145652173913043)), 11 -&gt; ScalarVector(ArrayBuffer(12.720833333333331, 27.59166666666667)), 20 -&gt; ScalarVector(ArrayBuffer(5.679999999999

// %% [markdown]
// ## Lets explore the clustering indices

// %%
val indicesAnalysis = new ClustersIndicesAnalysisLocal(newCC.data)
// Out:
// indicesAnalysis: org.clustering4ever.clustering.indices.ClustersIndicesAnalysisLocal[Long,org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],org.clustering4ever.clusterizables.EasyClusterizable,scala.collection.parallel.mutable.ParArray] = org.clustering4ever.clustering.indices.ClustersIndicesAnalysisLocal@40ad78f5

// %%
val internalIndices = InternalsIndices.values.toSeq.init
val extScores = indicesAnalysis.saveInternalsIndicesForEveryClusteringNumber(metric, internalIndices:_*)

val clusteringNumber = 5
// It is a tuple 3 as key, (MetricID, clusteringNumber, IndexEnum)
extScores.internalsIndicesByMetricClusteringNumberIndex.get(metric.id, clusteringNumber, internalIndices.head)

val oneInternalIndex = internalIndices.head

, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,...
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon0f766f00bafb33dbc5327e08e4848231&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;767395072&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul767395072"><li>
//               <a href="#tab767395072-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab767395072-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab767395072"><div class="tab-pane" id="tab767395072-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon75df1cdf3c71286ce97c8d7cc8f38d9f&quot;,&quot;dataInit&quot;:[{&quot;value3&quot;:0.6562894214936862,&quot;value1&quot;:1.112255597841987,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.7296790779172481,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.6881341430822359,&quot;value1&quot;:1.1662248813449434,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.8022960003412105,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.7134603364176307,&quot;value1&quot;:1.2091467986984328,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.8130566906422018,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.6815105723054911,&quot;value1&quot;:1.1549994929219976,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.7753951979912016,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.5840592929519481,&quot;value1&quot;:0.989842585880667,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.6691315763094605,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.6316589388627656,&quot;value1&quot;:1.0705127458523258,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.7284156318568762,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.767648039854906,&quot;value1&quot;:1.3009821605196514,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.8143527058433213,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.7776575164816134,&quot;value1&quot;:1.3179458598341784,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.8021392271672846,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.7844941054802967,&quot;value1&quot;:1.3295322638426783,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.8114771738186853,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.7856703198719887,&quot;value1&quot;:1.3315256694935633,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.8110798021498835,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.7247450257562306,&quot;value1&quot;:1.2282716824398145,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.7918591136045591,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.7962433429369037,&quot;value1&quot;:1.3494444469489415,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.864098733596484,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.8869654577797551,&quot;value1&quot;:1.5084189011134397,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.8885047178871827,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.7863645307959287,&quot;value1&quot;:1.3327021930835339,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.796487274322897,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.7677289679156585,&quot;value1&quot;:1.301119314472841,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.7739303174877262,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.8351383725272267,&quot;value1&quot;:1.415362337704526,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.8560458181421798,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.8488876359288978,&quot;value1&quot;:1.4636238584220242,&quot;key1&quot;:&quot;MI&quot;,&quot;key2&quot;:&quot;NMI_Sqrt&quot;,&quot;value2&quot;:0.8562197596033081,&quot;key3&quot;:&quot;NMI_Max&quot;},{&quot;value3&quot;:0.811067327267954,&quot;value1&quot;:1.3745675999581832,&quot;key1&quot;:&quot;M ...

// %% [markdown]
// ## Define a new vectorization

// %%
def newVecto(v: ScalarVector[mutable.ArrayBuffer[Double]]) = new ScalarVector(v.vector.toVector)

def newVecto2(v: ScalarVector[mutable.ArrayBuffer[Double]]) = new ScalarVector(v.vector.tail)

val vectorizationNature = Scalar

val vectorizationID1 = 1
val vectorizationID2 = 2

// Add vectorization of another kind that current one
val (cc3, implicitMappingTowardVector) = newCC.addVectorizationNature(vectorizationNature, vectorizationID1, newVecto)
// Add vectorization of same type that current one
val (cc4, implicitMappingTowardVector2) = cc3.addVectorizationNature(vectorizationID2, newVecto2)
// Update current vector for same type that current one
val cc5 = cc4.updateVector(vectorizationID2)

(cc4.data.head.v, cc5.data.head.v)
// Out:
// newVecto: (v: org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]])org.clustering4ever.vectors.ScalarVector[Vector[Double]]
// newVecto2: (v: org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]])org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]]
// vectorizationNature: org.clustering4ever.vectorizations.Scalar.type = org.clustering4ever.vectorizations.Scalar$@6ea35de9
// vectorizationID1: Int = 1
// vectorizationID2: Int = 2
// cc3: org.clustering4ever.clustering.chaining.ClusteringChainingLocal[Long,org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],org.clustering4ever.clusteri...
// (ScalarVector(ArrayBuffer(15.55, 28.65)),ScalarVector(ArrayBuffer(28.65)))

// %%
// Update current vector for different type that current one
val cc6 = cc5.updateVector[ScalarVector[Vector[Double]]](vectorizationNature, vectorizationID1)
cc6.data.head.v
// Out:
// cc6: org.clustering4ever.clustering.chaining.ClusteringChainingLocal[Long,org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],org.clustering4ever.vectors.ScalarVector[Vector[Double]],org.clustering4ever.clusterizables.EasyClusterizable,scala.collection.parallel.mutable.ParArray] = ClusteringChainingLocal(ParArray(EasyClusterizable(0,Vectorizable(ScalarVector(ArrayBuffer(15.55, 28.65))),ScalarVector(Vector(15.55, 28.65)),shapeless.HMap@2664117e,Vector(0, 3, 1, 0, 2, 2, 4, 2, 1, 2, 1, 3, 5, 2, 3, 2, 5, 1, 1, 6, 0, 2, 0, 3, 0, 4, 3, 7, 1, 1, 4, 4, 3, 6, 7, 7, 5, 8, 2, 0, 3, 2, 4, 9, 6, 5, 0, 4, 0, 9, 6, 4, 8, 11, 7, 3, 10, 12, 0, 12, 9, 0, 7, 2, 10, 12, 0, 5, 7, 0, 4, 3, 4, 9, 0, 11, 7, 7, 14, 0, 15, 6, 14, 16, 5, 0, 6, 8, 12, 2, 2, 9, 9, 3, 11, 17, 15, 1...
// ScalarVector(Vector(15.55, 28.65))

// %%
val metricVector = new Euclidean[Vector[Double]](false)


val generateAlgoForList = (23 to 30).map( i => KMeansArgs(i, metricVector, 0.0001, 50) ).map(_.obtainAlgorithm(cc6.data))

val cc7 = cc6.runAlgorithms(generateAlgoForList:_*)
// Out:
// metricVector: org.clustering4ever.math.distances.scalar.Euclidean[Vector[Double]] = Euclidean distance without squared root applied
// generateAlgoForList: scala.collection.immutable.IndexedSeq[org.clustering4ever.scala.clustering.kcenters.KMeans[Long,org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],Vector[Double],org.clustering4ever.clusterizables.EasyClusterizable,org.clustering4ever.math.distances.scalar.Euclidean,scala.collection.parallel.mutable.ParArray]] = Vector(KMeans(KMeansArgs(23,Euclidean distance without squared root applied,1.0E-4,50,Map())), KMeans(KMeansArgs(24,Euclidean distance without squared root applied,1.0E-4,50,Map())), KMeans(KMeansArgs(25,Euclidean distance without squared root applied,1.0E-4,50,Map())), KMeans(KMeansArgs(26,Eu...

// %%
val cc8 = cc7.updateVector[ScalarVector[mutable.ArrayBuffer[Double]]](Default, vectorizationID2)

cc8.data.head.clusterIDs
// Out:
// cc8: org.clustering4ever.clustering.chaining.ClusteringChainingLocal[Long,org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],org.clustering4ever.vectors.ScalarVector[scala.collection.mutable.ArrayBuffer[Double]],org.clustering4ever.clusterizables.EasyClusterizable,scala.collection.parallel.mutable.ParArray] = ClusteringChainingLocal(ParArray(EasyClusterizable(0,Vectorizable(ScalarVector(ArrayBuffer(15.55, 28.65))),ScalarVector(ArrayBuffer(28.65)),shapeless.HMap@2664117e,Vector(0, 3, 1, 0, 2, 2, 4, 2, 1, 2, 1, 3, 5, 2, 3, 2, 5, 1, 1, 6, 0, 2, 0, 3, 0, 4, 3, 7, 1, 1, 4, 4, 3, 6, 7, 7, 5, 8, 2, 0, 3, 2, 4, 9, 6, 5, 0, 4, 0, 9, 6, 4, 8, 11, 7, 3, 10, 12, 0, 12, 9, 0, 7, 2, 10, 12, 0, 5, 7, 0, 4, 3, 4, 9, 0, 11, 7, 7, 14, 0, 15, 6, 14, 16, 5, 0, 6, 8, 12, ...
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;an